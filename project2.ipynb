# %% [markdown]
#    <center><font size="5"><b>Volcanos of the World & Eruption Trends</b></font></center>

# %% [markdown]
# **Introduction**

# %% [markdown]
# This is a project that will examine volcanos around the world and the patterns that emerge in their erruptions. We will also examine how these erruptions impact human civilizations in areas close to these volcanos.

# %% [markdown]
# **Dataset Creation**

# %% [markdown]
# First, I imported all the necessary libraries.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Next, I imported data as Pandas DataFrames.

# %%
volcanos_temp = pd.read_csv('volcanos.csv')
eruptions_temp = pd.read_csv('eruptions.csv')
events_temp = pd.read_csv('events.csv')

# %% [markdown]
# *The first five rows of the volcanos dataframe.*

# %%
volcanos_temp.head()
# Out:
#    volcano_number     volcano_name primary_volcano_type last_eruption_year  \
# 0          283001              Abu            Shield(s)              -6850
# 1          355096       Acamarachi        Stratovolcano            Unknown
# 2          342080       Acatenango    Stratovolcano(es)               1972
# 3          213004  Acigol-Nevsehir              Caldera              -2080
# 4          321040            Adams        Stratovolcano                950
#
#          country                          region  \
# 0          Japan         Japan, Taiwan, Marianas
# 1          Chile                   South America
# 2      Guatemala      México and Central America
# 3         Turkey  Mediterranean and Western Asia
# 4  United States          Canada and Western USA
#
#                                subregion  latitude  longitude  elevation  ...  \
# 0                                 Honshu    34.500    131.600        641  ...
# ...

# %%
volcanos = volcanos_temp[['volcano_number', 'volcano_name', 'primary_volcano_type', 
                          'last_eruption_year', 'country', 'latitude', 'longitude',
                          'elevation', 'population_within_5_km', 'population_within_10_km',
                         'population_within_30_km', 'population_within_100_km']]
volcanos
# Out:
#      volcano_number              volcano_name primary_volcano_type  \
# 0            283001                       Abu            Shield(s)
# 1            355096                Acamarachi        Stratovolcano
# 2            342080                Acatenango    Stratovolcano(es)
# 3            213004           Acigol-Nevsehir              Caldera
# 4            321040                     Adams        Stratovolcano
# ..              ...                       ...                  ...
# 953          300242                    Zimina    Stratovolcano(es)
# 954          341061  Zitacuaro-Valle de Bravo              Caldera
# 955          221020              Zubair Group               Shield
# 956          221021                     Zukur               Shield
# 957          327120              Zuni-Bandera       Volcanic field
#
#     last_eruption_year        country  latitude  longitude  elevation  \
# 0                -6850          Japan    34.500    131.600        641
# ...

# %% [markdown]
# *The first five rows of the eruptions dataframe.*

# %%
eruptions_temp.head()
# Out:
#    volcano_number            volcano_name  eruption_number  \
# 0          266030                 Soputan            22354
# 1          343100              San Miguel            22355
# 2          233020  Fournaise, Piton de la            22343
# 3          345020      Rincon de la Vieja            22346
# 4          353010              Fernandina            22347
#
#     eruption_category area_of_activity  vei  start_year  start_month  \
# 0  Confirmed Eruption              NaN  NaN      2020.0          3.0
# 1  Confirmed Eruption              NaN  NaN      2020.0          2.0
# 2  Confirmed Eruption              NaN  NaN      2020.0          2.0
# 3  Confirmed Eruption              NaN  NaN      2020.0          1.0
# 4  Confirmed Eruption              NaN  NaN      2020.0          1.0
#
#    start_day   evidence_method_dating  end_year  end_month  end_day  latitude  \
# 0       23.0  Historical Observations    2020.0        4.0      2.0     1.112
# ...

# %%
eruptions = eruptions_temp[['volcano_number', 'volcano_name', 'eruption_number', 
                          'eruption_category', 'start_year', 'start_month', 'start_day',
                          'end_year', 'end_month', 'end_day','latitude', 'longitude']]
eruptions
# Out:
#        volcano_number            volcano_name  eruption_number  \
# 0              266030                 Soputan            22354
# 1              343100              San Miguel            22355
# 2              233020  Fournaise, Piton de la            22343
# 3              345020      Rincon de la Vieja            22346
# 4              353010              Fernandina            22347
# ...               ...                     ...              ...
# 11173          324020     Craters of the Moon            21101
# 11174          222161            Igwisi Hills            22141
# 11175          357121            Quetrupillan            22351
# 11176          357121            Quetrupillan            22352
# 11177          390090                Saunders            21099
#
#         eruption_category  start_year  start_month  start_day  end_year  \
# 0      Confirmed Eruption      2020.0          3.0       23.0    2020.0
# ...

# %% [markdown]
# *The first five rows of events dataframe.*

# %%
events_temp.head()
# Out:
#    volcano_number     volcano_name  eruption_number  eruption_start_year  \
# 0          210020  Chaine des Puys            10011                -4040
# 1          210020  Chaine des Puys            10011                -4040
# 2          210020  Chaine des Puys            10011                -4040
# 3          210020  Chaine des Puys            10011                -4040
# 4          210020  Chaine des Puys            10011                -4040
#
#    event_number             event_type event_remarks  event_date_year  \
# 0        100001              Explosion           NaN              NaN
# 1        100002                 Scoria           NaN              NaN
# 2        100003       Pyroclastic flow           NaN              NaN
# 3        100004           Lava flow(s)           NaN              NaN
# 4        100005  Cinder cone formation           NaN              NaN
#
#    event_date_month  event_date_day
# 0               NaN             NaN
# ...

# %%
events = events_temp[['volcano_number', 'volcano_name', 'eruption_number', 
                      'event_number', 'event_type']]
events
# Out:
#        volcano_number     volcano_name  eruption_number  event_number  \
# 0              210020  Chaine des Puys            10011        100001
# 1              210020  Chaine des Puys            10011        100002
# 2              210020  Chaine des Puys            10011        100003
# 3              210020  Chaine des Puys            10011        100004
# 4              210020  Chaine des Puys            10011        100005
# ...               ...              ...              ...           ...
# 41317          261080         Sinabung            15404        153198
# 41318          357121     Quetrupillan            22349        153199
# 41319          357121     Quetrupillan            22350        153200
# 41320          357121     Quetrupillan            22351        153201
# 41321          357121     Quetrupillan            22352        153202
#
#                     event_type
# 0                    Explosion
# 1                       Scoria
# ...

# %% [markdown]
# *Could use data for this to determine severity of erruption by using event_type to see if it is an explosion or if lava flow is reported*

# %%
volcanos.to_csv('/Users/Chris/Desktop/School-Stuff/INFO-3300/Project-2/volcanos.csv', encoding='utf-8', index=False)
eruptions.to_csv('/Users/Chris/Desktop/School-Stuff/INFO-3300/Project-2/eruptions.csv', encoding='utf-8', index=False)
events.to_csv('/Users/Chris/Desktop/School-Stuff/INFO-3300/Project-2/events.csv', encoding='utf-8', index=False)

# %% [markdown]
# **Data Description**

# %% [markdown]
# Three different datasets containing information about volcanos and eruptions throughout recorded history. Dataset one contains information about volcanos around the world. Dataset two contains information about reported erruptions and which volcano it occured at. Dataset three contains information about these specific erruptions.

# %% [markdown]
# **Data Sources**

# %% [markdown]
# First Dataset (Volcanos): https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/volcano.csv
#
# Second Dataset (Erruptions): https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/eruptions.csv
#
# Third Dataset (Events): https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/events.csv
